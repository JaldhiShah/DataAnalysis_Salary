# %%
import pandas as pd

# %%
df=pd.read_csv("S.csv")

# %%
df.sample(10)
# Out:
#                        Company Name       Job Title  Salaries Reported  \
# 3262                             DC   Data Engineer                1.0
# 2587             McKinsey & Company    Data Analyst                7.0
# 1857                            ABC  Data Scientist                1.0
# 1281                       Mahindra    Data Science                1.0
# 1618                        Fractal  Data Scientist                3.0
# 517                    Tech Systems  Data Scientist                1.0
# 754          Tricog Health Services  Data Scientist                1.0
# 3295  Tata Consultancy Services Big   Data Engineer                6.0
# 1194                        WebShar  Data Scientist                1.0
# 3738                       Teradata   Data Engineer                1.0
#
#        Location         Salary
# 3262       Pune   ₹3,61,080/yr
# 2587  New Delhi  ₹14,01,954/yr
# 1857     Mumbai     $96,739/yr
# 1281       Pune     ₹16,979/mo
# ...

# %%
import numpy as np

# %%
df.describe()
# Out:
#        Salaries Reported
# count        4342.000000
# mean            2.775910
# std             5.146527
# min             1.000000
# 25%             1.000000
# 50%             1.000000
# 75%             3.000000
# max           105.000000
